# %% [markdown]
# # INDIVIDUAL PROJECT
#
# In this final project, you will focus on exploratory data analysis of stock prices. Keep in mind, this project is just meant to practice your visualization and pandas skills, it is not meant to be a robust financial analysis or be taken as financial advice
#
# ------
# You will focus on bank stocks and see how they progressed throughout the [ financial crisis](https://en.wikipedia.org/wiki/Financial_crisis_of_2007%E2%80%9308) all the way to November 20th, 2023.

# %% [markdown]
# # Get The Data
# In this section, you will learn how to use pandas to directly read from Yahoo finance.
# First, you will need to install pandas_datareader (**pip install yfinance**), which will allow to to [read stock information directly from the internet](https://finance.yahoo.com/u/yahoo-finance/watchlists/bank-and-financial-services-stocks/)

# %% [markdown]
# # Import Library
# The Necesary Libraries have been imported for you already

# %%
# Import the Necessary Libraries
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt

# %%
# You may need to install Yahoo Finance first
#!pip install yfinance

# %% [markdown]
# # Data
# You need to get data using yahoo finance. You will get stock information for the following:
# * Bank Of America
# * Amazon
# * CitiGroup
# * Goldman Sachs
# * JPMorgan Chase
# * Morgan Stanley
# * Wells Fargo
#
# ** Find the stock data from Jan 1st, 2006 to Novemebr 20 th 2023 for each of these banks.
#
# I. First, set each bank to be a separat dataframe, with the variable name for that bank being its ticker symbol. And then combine them using the concat method.
#
# II. Second, find the stock data altogether
#
# This will involve few steps

# %% [markdown]
# ### I. Setting the stock data for each bank separately and then combine
# * then as one single dataframe using pd.concat

# %%
# Step 1 import yfinance as yf
import yfinance as yf
import seaborn as sns

# %%
# Step 2: Set the start and the end as follow:
start = "2006-01-01"
end = "2023-11-20"

# %%
#Step 3:
#For the Signature Bank stock, you use yahoo finance (yf) and 
# the ticker name symbol "SBNY" for Signature Bank
SBNY = yf.download('SBNY', start, end)

# For the Silicon Valey Bank
SIVBQ = yf.download('SIVBQ', start, end)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
# Step 4: set the tickers, using the stiker symbol for each Bank
tickers = ['SBNY','SIVBQ']

# %% [markdown]
# * Now, use pd.concat to concatenate the Banks DataFrames together
#     to a single data frame called stock_df

# %%
# Step 5: Use pandas to combine these two data as one dataframe
stock_df = pd.concat([SBNY,SIVBQ], axis=1, keys=tickers)

# %%
# Setp 6: Check the first five row of these data
stock_df.head()
# Out:
#                  SBNY                                                      \
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 2006-01-03  28.090000  28.620001  27.900000  28.500000  26.421669  377593
# 2006-01-04  28.450001  28.719999  28.290001  28.500000  26.421669  314188
# 2006-01-05  28.299999  28.500000  28.299999  28.400000  26.328959   48196
# 2006-01-06  28.650000  28.790001  28.150000  28.590000  26.505106   90469
# 2006-01-09  28.700001  28.820000  28.469999  28.799999  26.699793   87657
#
#                 SIVBQ
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2006-01-03  47.270000  47.340000  45.849998  46.549999  46.549999   519084.0
# 2006-01-04  46.330002  46.770000  45.950001  46.130001  46.130001  1026640.0
# 2006-01-05  46.000000  46.400002  45.680000  45.700001  45.700001   581344.0
# 2006-01-06  45.700001  46.810001  45.700001  46.700001  46.700001   762263.0
# 2006-01-09  46.570000  46.799999  46.419998  46.669998  46.669998   456720.0

# %%
# You can plot individual stock. What can you say about 
# the Signature Bank?

SBNY['Open'].plot()
sns.despine()

# %% [markdown]
#  # Task 1
#  * ## Mimic step 1 through step 6
#
#  to access the stock data of
#  * Amazon
# * Bank Of America
# * CitiGroup
# * Goldman Sachs
# * JPMorgan Chase
# * Morgan Stanley
#
# from Jan 1st, 2006 to Novemebr 15th 2023 for each of these banks.
# Set each bank to be a separat dataframe, with the variable name for that bank being its ticker symbol. You find the ticker symbol for each Company. Use pandas to combine as a single dataframe, called stocks_df

# %%
# Amazon
AMZ = yf.download('AMZN', start, end)
# Bank of America
BAC = yf.download('BAC', start, end)
# JPMorgan Chase
JPM = yf.download('JPM',start, end)
# City Group
C = yf.download('C',start, end)
# Goldman Sachs
GS = yf.download('GS',start, end)
# Morgan Stanley
MS = yf.download('MS',start, end)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
# Create a list of tickers for thes stocks and call it tickers
#tickers = [?????]

# %%
tickers = ['AMZN', 'BAC', 'JPM', 'C', 'GS', 'MS']

# %%
#use set_option to display all 36 columns of the stocks_df
pd.set_option('display.max_columns', 36)

# %%
stocks_df = pd.concat([AMZ,BAC,C, GS,JPM,MS],axis=1,keys=tickers)
stocks_df.columns.names = ['Bank Ticker','Stock Info']

# %%
# Check the first five rows of the stocks_df
stocks_df.head(2)
# Out:
# Bank Ticker    AMZN                                                     BAC  \
# Stock Info     Open    High     Low   Close Adj Close     Volume       Open
# Date
# 2006-01-03   2.3735  2.3925  2.3125  2.3790    2.3790  151644000  46.919998
# 2006-01-04   2.3745  2.3865  2.3345  2.3625    2.3625  148818000  47.000000
#
# Bank Ticker                                                               JPM  \
# Stock Info        High        Low      Close  Adj Close    Volume        Open
# Date
# 2006-01-03   47.180000  46.150002  47.080002  32.168694  16296700  490.000000
# 2006-01-04   47.240002  46.450001  46.580002  31.827045  17757900  488.600006
#
# Bank Ticker                                                           \
# Stock Info         High         Low       Close   Adj Close   Volume
# Date
# 2006-01-03   493.799988  481.100006  492.899994  338.403259  1537600
# 2006-01-04   491.000000  483.500000  483.799988  332.155609  1870960
#
# Bank Ticker           C                                                 \
# Stock Info         Open        High         Low       Close  Adj Close
# Date
# 2006-01-03   126.699997  129.440002  124.230003  128.869995  98.085442
# 2006-01-04   127.349998  128.910004  126.379997  127.089996  96.730675
#
# Bank Ticker                  GS                                              \
# Stock Info    Volume       Open       High        Low      Close  Adj Close
# Date
# 2006-01-03   6188700  39.830002  40.360001  39.299999  40.189999  24.948782
# 2006-01-04   4861600  39.779999  40.139999  39.419998  39.619999  24.804779
#
# Bank Ticker                   MS                                              \
# Stock Info     Volume       Open       High        Low      Close  Adj Close
# Date
# 2006-01-03   12838600  57.169998  58.490002  56.740002  58.310001  33.585464
# 2006-01-04   13491500  58.700001  59.279999  58.349998  58.349998  33.608490
#
# Bank Ticker
# Stock Info    Volume
# Date
# 2006-01-03   5377000
# 2006-01-04   7977800

# %%
# Part II. Access all stocks once and call that dataframe stocks.

# For example: to access Signature Bank and Silcon Valey Bank data,
# we use
stock_df = yf.download(['SBNY','SIVBQ'],start, end)
# Out:
# [*********************100%%**********************]  2 of 2 completed

# %%
# Check the first five rows of the dataframe
stock_df.head()
# Out:
#             Adj Close                 Close                  High             \
#                  SBNY      SIVBQ       SBNY      SIVBQ       SBNY      SIVBQ
# Date
# 2006-01-03  26.421669  46.549999  28.500000  46.549999  28.620001  47.340000
# 2006-01-04  26.421669  46.130001  28.500000  46.130001  28.719999  46.770000
# 2006-01-05  26.328959  45.700001  28.400000  45.700001  28.500000  46.400002
# 2006-01-06  26.505106  46.700001  28.590000  46.700001  28.790001  46.810001
# 2006-01-09  26.699793  46.669998  28.799999  46.669998  28.820000  46.799999
#
#                   Low                  Open             Volume
#                  SBNY      SIVBQ       SBNY      SIVBQ    SBNY      SIVBQ
# Date
# 2006-01-03  27.900000  45.849998  28.090000  47.270000  377593   519084.0
# 2006-01-04  28.290001  45.950001  28.450001  46.330002  314188  1026640.0
# 2006-01-05  28.299999  45.680000  28.299999  46.000000   48196   581344.0
# 2006-01-06  28.150000  45.700001  28.650000  45.700001   90469   762263.0
# 2006-01-09  28.469999  46.419998  28.700001  46.570000   87657   456720.0

# %% [markdown]
#  Do the same thing using the
#  to access the stock data of
# * Bank Of America
# * CitiGroup
# * Goldman Sachs
# * JPMorgan Chase
# * Morgan Stanley
# * Wells Fargo
#
# and call that dataframe "stocks"

# %%
# Your code here
# Bank of America
BAC = yf.download('BAC', start, end)
# City Group
C = yf.download('C',start, end)
# Goldman Sachs
GS = yf.download('GS',start, end)
# JPMorgan Chase
JPM = yf.download('JPM',start, end)
# Morgan Stanley
MS = yf.download('MS',start, end)
#Wells Fargo
WFC = yf.download('WFC', start, end)
# Amazon
AMZ = yf.download('AMZN', start, end)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
tickers = ['BAC', 'C', 'GS', 'JPM', 'MS', 'WFC', 'AMZ']

# %%
stocks = pd.concat([BAC, C, GS, JPM, MS, WFC, AMZ], axis = 1, keys = tickers)

# %%
stocks
# Out:
#                   BAC                                                        \
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2006-01-03  46.919998  47.180000  46.150002  47.080002  32.168694  16296700
# 2006-01-04  47.000000  47.240002  46.450001  46.580002  31.827045  17757900
# 2006-01-05  46.580002  46.830002  46.320000  46.639999  31.868053  14970700
# 2006-01-06  46.799999  46.910000  46.349998  46.570000  31.820229  12599800
# 2006-01-09  46.720001  46.970001  46.360001  46.599998  31.840717  15619400
# ...               ...        ...        ...        ...        ...       ...
# 2023-11-13  27.540001  27.850000  27.420000  27.700001  27.480667  28521800
# 2023-11-14  28.500000  29.410000  28.469999  29.219999  28.988630  66676300
# 2023-11-15  29.200001  29.730000  29.200001  29.620001  29.385464  46968900
# 2006-01-06   488.799988  489.000000  482.000000  486.200012  333.803314
# 2006-01-09   486.000000  487.399994  483.000000  483.899994  332.224304
#
# Bank Ticker                   GS                                      \
# Stock Info    Volume        Open        High         Low       Close
# Date
# 2006-01-03   1537600  126.699997  129.440002  124.230003  128.869995
# 2006-01-04   1870960  127.349998  128.910004  126.379997  127.089996
# 2006-01-05   1143160  126.000000  127.320000  125.610001  127.040001
# 2006-01-06   1370210  127.290001  129.250000  127.290001  128.839996
# 2006-01-09   1680740  128.500000  130.619995  128.000000  130.389999
#
# Bank Ticker                      ...         MS                        \
# Stock Info   Adj Close   Volume  ...       Open       High        Low
# Date                             ...
# 2006-01-03   98.085442  6188700  ...  57.169998  58.490002  56.740002
# 2006-01-04   96.730675  4861600  ...  58.700001  59.279999  58.349998
# 2006-01-05   96.692619  3717400  ...  58.549999  58.590000  58.020000
# 2006-01-06   98.062614  4319600  ...  58.770000  58.849998  58.049999
# 2006-01-09   99.242393  4723500  ...  58.630001  59.290001  58.619999
#
# Bank Ticker                                       WFC                        \
# Stock Info       Close  Adj Close   Volume       Open       High        Low
# Date
# 2006-01-03   58.310001  33.585464  5377000  31.600000  31.975000  31.195000
# 2006-01-04   58.349998  33.608490  7977800  31.799999  31.820000  31.365000
# 2006-01-05   58.509998  33.700645  5778000  31.500000  31.555000  31.309999
# 2006-01-06   58.570000  33.735214  6889800  31.580000  31.775000  31.385000
# 2006-01-09   59.189999  34.092323  4144500  31.674999  31.825001  31.555000
#
# Bank Ticker                                     AMZ                          \
# Stock Info       Close  Adj Close    Volume    Open    High     Low   Close
# Date
# 2006-01-03   31.900000  19.369591  11016400  2.3735  2.3925  2.3125  2.3790
# 2006-01-04   31.530001  19.144926  10870000  2.3745  2.3865  2.3345  2.3625
# 2006-01-05   31.495001  19.123682  10158000  2.3580  2.4100  2.3555  2.3825
# 2006-01-06   31.680000  19.236012   8403800  2.3985  2.4290  2.3660  2.3935
# 2006-01-09   31.674999  19.232965   5619600  2.3275  2.3550  2.3200  2.3540
#
# Bank Ticker
# Stock Info  Adj Close     Volume
# Date
# 2006-01-03     2.3790  151644000
# 2006-01-04     2.3625  148818000
# 2006-01-05     2.3825  108344000
# 2006-01-06     2.3935  123058000
# 2006-01-09     2.3540  178862000
#
# [5 rows x 42 columns]

# %% [markdown]
# # Task 2
#  * # EDA
# Let's explore the data a bit!

# %%
# What is the maximum Close Price for each Stock?
#(Hint use the stocks dataframe)
# Your code here
for i in tickers:
    print(i)
    print(stocks[i]['Close'].max())
# Out:
# BAC
# 54.900001525878906
# C
# 564.0999755859375
# GS
# 423.8500061035156
# JPM
# 171.77999877929688
# MS
# 108.7300033569336
# WFC
# 65.93000030517578
# AMZ
# 186.57049560546875

# %% [markdown]
#  Create a new empty DataFrame called returns. This dataframe
# will contain the returns for each stock. Returns are obtained by
# $$r_t=\frac{p_t-p_{t-1}}{p_{t-1}}=\frac{p_t}{p_{t-1}}-1$$

# %%
returns = pd.DataFrame()
returns_dictonary = []

# %% [markdown]
#  Use pandas pct_change() method on the Close column to create a column
#  representing this return value and store that result to the returns.

# %%
for i in tickers: 
    
   returns[f'{i}_returns'] = stocks[i][['Close']].pct_change()

# %%
returns
# Out:
#             BAC_returns  C_returns  GS_returns  JPM_returns  MS_returns  \
# Date
# 2006-01-03          NaN        NaN         NaN          NaN         NaN
# 2006-01-04    -0.010620  -0.018462   -0.013812    -0.014183    0.000686
# 2006-01-05     0.001288   0.004961   -0.000393     0.003029    0.002742
# 2006-01-06    -0.001501   0.000000    0.014169     0.007046    0.001025
# 2006-01-09     0.000644  -0.004731    0.012030     0.016242    0.010586
# ...                 ...        ...         ...          ...         ...
# 2023-11-13     0.000723   0.014734    0.004301    -0.004439   -0.003850
# 2023-11-14     0.054874   0.038876    0.036126     0.018247    0.043577
# 2023-11-15     0.013689   0.011722   -0.003307     0.008758    0.017495
# 2023-11-16    -0.002701  -0.004679   -0.002755     0.011420   -0.000251
# 2023-11-17     0.014895   0.015447    0.007485     0.009046    0.007783
#
#             WFC_returns  AMZ_returns
# Date
# 2006-01-03          NaN          NaN
# 2006-01-04    -0.011599    -0.006936
# 2006-01-05    -0.001110     0.008466
# 2006-01-06     0.005874     0.004617
# 2006-01-09    -0.000158    -0.016503
# ...                 ...          ...
# 2023-11-13    -0.002935    -0.006757
# 2023-11-14     0.032132     0.022512
# 2023-11-15     0.018061    -0.017833
# 2023-11-16    -0.007236    -0.002584
# 2023-11-17     0.010111     0.016453
#
# [4501 rows x 7 columns]

# %%
returns.dropna(inplace = True)

# %%
#pd.DataFrame(returns_dictonary)

# %%
# Check the first five rows of the returns
returns.head()
# Out:
#             BAC_returns  C_returns  GS_returns  JPM_returns  MS_returns  \
# Date
# 2006-01-04    -0.010620  -0.018462   -0.013812    -0.014183    0.000686
# 2006-01-05     0.001288   0.004961   -0.000393     0.003029    0.002742
# 2006-01-06    -0.001501   0.000000    0.014169     0.007046    0.001025
# 2006-01-09     0.000644  -0.004731    0.012030     0.016242    0.010586
# 2006-01-10    -0.008369   0.003100    0.012578     0.001475    0.000507
#
#             WFC_returns  AMZ_returns
# Date
# 2006-01-04    -0.011599    -0.006936
# 2006-01-05    -0.001110     0.008466
# 2006-01-06     0.005874     0.004617
# 2006-01-09    -0.000158    -0.016503
# 2006-01-10    -0.000789    -0.030374

# %% [markdown]
# Using this returns DataFrame, figure out what dates each bank stock had the best and worst single day returns.You should notice that 3 of the banks have the same worst drop, did anything significant happen that day? Keep inmind that you are returning the index (date) and not the actual stock return value.

# %%
returns.idxmin()
# Out:
# BAC_returns   2009-01-20
# C_returns     2009-02-27
# GS_returns    2009-01-20
# JPM_returns   2009-01-20
# MS_returns    2008-10-09
# WFC_returns   2009-01-20
# AMZ_returns   2006-07-26
# 2023-11-13   140.669998  142.589996  142.589996   35680600
# 2023-11-14   144.679993  145.800003  145.800003   56674600
# 2023-11-15   142.589996  143.199997  143.199997   63875700
# 2023-11-16   139.520004  142.830002  142.830002   49653500
# 2023-11-17   142.539993  145.179993  145.179993   49636700
#
# [4501 rows x 42 columns]

# %%
plt.figure(figsize=(14, 7))
adj_close_data = stocks
for i in tickers: 
    plt.plot(adj_close_data[i].index, adj_close_data[i]['Close'], label=i)
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.title('Closing Price Over Time')
plt.legend()

# %% [markdown]
# Create a pairplot using seaborn of the returns dataframe. What stock stands out to you? Why?

# %%
#Your code here
sns.pairplot(returns)

# %%
# Do histogram plot, for each of these stocks.
# Your code here

fig = plt.figure(figsize = (14,7))
ax = fig.gca()
returns.hist(ax = ax, bins = 50)

      #
# Out:
# /var/folders/3c/c1bd5yqj5nb6rf_0sw8yb7w80000gn/T/ipykernel_950/3937380355.py:6: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   returns.hist(ax = ax, bins = 50)
# array([[<Axes: title={'center': 'BAC_returns'}>,
#         <Axes: title={'center': 'C_returns'}>,
#         <Axes: title={'center': 'GS_returns'}>],
#        [<Axes: title={'center': 'JPM_returns'}>,
#         <Axes: title={'center': 'MS_returns'}>,
#         <Axes: title={'center': 'WFC_returns'}>],
#        [<Axes: title={'center': 'AMZ_returns'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %% [markdown]
# # Moving Average

# %% [markdown]
# Plot the 30-day moving averages for JPM CHASE and Morgan Stanley stocks for the first 600 days. Use will need to use the individual daframe that you have create for each stock in Part I.

# %%
# Your code here
jpm_df = JPM['Close'].rolling(window = 30).mean().dropna().iloc[:600]

# %%
jpm_df
# Out:
# Date
# 2006-02-14    39.623333
# 2006-02-15    39.627666
# 2006-02-16    39.667666
# 2006-02-17    39.702333
# 2006-02-21    39.725000
#                 ...
# 2008-06-26    40.830000
# 2008-06-27    40.431000
# 2008-06-30    40.023667
# 2008-07-01    39.624667
# 2008-07-02    39.321333
# Name: Close, Length: 600, dtype: float64

# %%
ms_df = MS['Close'].rolling(window = 30).mean().dropna().iloc[:600]

# %%
ms_df
# Out:
# Date
# 2006-02-14    59.789333
# 2006-02-15    59.874333
# 2006-02-16    59.972667
# 2006-02-17    60.049333
# 2006-02-21    60.122667
#                 ...
# 2008-06-26    41.654333
# 2008-06-27    41.287667
# 2008-06-30    40.916334
# 2008-07-01    40.596333
# 2008-07-02    40.298667
# Name: Close, Length: 600, dtype: float64

# %%
plt.figure(figsize = (14,7))
plt.plot(jpm_df.index, jpm_df,marker = 'o', label = 'jpm 30 day ma')
plt.plot(ms_df.index, ms_df,marker = 'o', label = 'ms 30 day ma')
plt.title('30 day moving avarage of JPM Chase and Morgan Stanley')
plt.xlabel('Date')
plt.ylabel('Avarage Price')
plt.legend()
plt.show()

# %% [markdown]
# # Excellent Job!
